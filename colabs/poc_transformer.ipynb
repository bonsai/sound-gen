# %% [markdown]
# # POC: Transformer
#
# 📖 対応記事: `親子対話：Transformer`🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9ATransformer.md)

# %%
# @title Setup
# !pip install -q torch numpy matplotlib

# %%
# @title Demo
# Minimal Transformer Block
import torch
import torch.nn as nn

class TinyTransformer(nn.Module):
  def __init__(self, d_model=64, nhead=4):
    super().__init__()
    self.attn = nn.MultiheadAttention(d_model, nhead, batch_first=True)
    self.ffn = nn.Sequential(
      nn.Linear(d_model, d_model*4),
      nn.ReLU(),
      nn.Linear(d_model*4, d_model)
    )
    self.norm1 = nn.LayerNorm(d_model)
    self.norm2 = nn.LayerNorm(d_model)

  def forward(self, x):
    x2 = self.norm1(x + self.attn(x, x, x)[0])
    return self.norm2(x2 + self.ffn(x2))

model = TinyTransformer()
x = torch.randn(2, 10, 64)
out = model(x)
print(f"✅ Transformer block: {x.shape} → {out.shape}")

# %% [markdown]
# ---
# ### 📝 まとめ
# TODO
#
# 🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9ATransformer.md)
