# %% [markdown]
# # POC: Encoder
#
# 📖 対応記事: `親子対話：Encoder`🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9AEncoder.md)

# %%
# @title Setup
# !pip install -q torch numpy matplotlib

# %%
# @title Demo
# Simple Audio Encoder (Autoencoder)
import torch
import torch.nn as nn

class AudioEncoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.conv = nn.Sequential(
      nn.Conv1d(1, 16, 3, 2, 1), nn.ReLU(),
      nn.Conv1d(16, 32, 3, 2, 1), nn.ReLU(),
      nn.Conv1d(32, 64, 3, 2, 1), nn.ReLU(),
    )

  def forward(self, x):
    return self.conv(x)

model = AudioEncoder()
dummy = torch.randn(1, 1, 16000)
out = model(dummy)
print(f"Encoder: 16000 samples → {out.shape[2]} frames × {out.shape[1]} channels")
print(f"✅ Compression ratio: {16000 / out.shape[2]:.1f}x")

# %% [markdown]
# ---
# ### 📝 まとめ
# TODO
#
# 🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9AEncoder.md)
