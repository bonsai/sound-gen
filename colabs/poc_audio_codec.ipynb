# %% [markdown]
# # POC: 音声コーデック (EnCodec)
#
# 📖 対応記事: `親子対話：音声コーデック`🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9A%E9%9F%B3%E5%A3%B0%E3%82%B3%E3%83%BC%E3%83%87%E3%83%83%E3%82%AF.md)

# %%
# @title Setup
# !pip install -q encodec torchaudio

# %%
# @title Demo
# Neural Audio Codec (EnCodec POC)
# !pip install -q encodec torchaudio

from encodec import EncodecModel
from encodec.utils import convert_audio
import torchaudio
import torch

# Load EnCodec
model = EncodecModel.encodec_model_24khz()

# Generate sine wave
sr = 24000
t = torch.linspace(0, 2, sr*2)
audio = torch.sin(2*torch.pi*440*t).unsqueeze(0).unsqueeze(0)

# Encode/Decode
with torch.no_grad():
  encoded = model.encode(audio)
  decoded = model.decode(encoded)

print(f"Original:  {audio.shape[-1]} samples")
print(f"Compressed: {encoded[0][0].shape[-1]} frames")
print(f"✅ Compression ratio: {audio.shape[-1] / encoded[0][0].shape[-1]:.0f}x")

# %% [markdown]
# ---
# ### 📝 まとめ
# TODO
#
# 🔗 [記事を読む](https://github.com/bonsai/sound-gen/blob/main/articles/%E8%A6%AA%E5%AD%90%E5%AF%BE%E8%A9%B1%EF%BC%9A%E9%9F%B3%E5%A3%B0%E3%82%B3%E3%83%BC%E3%83%87%E3%83%83%E3%82%AF.md)
